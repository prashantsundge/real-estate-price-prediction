# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# %%
df= pd.read_csv("data/processed/clean_df.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1500 non-null   object
#  1   Price (INR)        1500 non-null   object
#  2   Description        985 non-null    object
#  3   Transaction        1500 non-null   object
#  4   Furnishing         1500 non-null   object
#  5   Bathroom           1498 non-null   float64
#  6   Possession         1498 non-null   object
#  7   Price per Sqft     1419 non-null   object
#  8   Society            1500 non-null   object
#  9   Total Area         1500 non-null   float64
#  10  Covered_parking    1500 non-null   int64
#  11  Open_parking       1500 non-null   int64
#  12  Possession_Status  1500 non-null   object
#  13  BHK                1500 non-null   float64
#  14  Price_INR_Numeric  1500 non-null   float64
# dtypes: float64(4), int64(2), object(9)
# ...

# %%
df.describe()
# Out:
#           Bathroom    Total Area  Covered_parking  Open_parking          BHK  \
# count  1498.000000   1500.000000      1500.000000   1500.000000  1500.000000
# mean      2.458611   1391.596000         0.354000      0.020667     2.439333
# std       1.393259    851.720632         0.750817      0.273781     1.323942
# min       0.000000      0.000000         0.000000      0.000000     0.000000
# 25%       2.000000   1100.000000         0.000000      0.000000     2.000000
# 50%       3.000000   1410.000000         0.000000      0.000000     3.000000
# 75%       3.000000   1750.000000         1.000000      0.000000     3.000000
# max      10.000000  15000.000000        10.000000      9.000000    10.000000
#
#        Price_INR_Numeric
# count       1.500000e+03
# mean        1.347240e+07
# std         3.844128e+07
# min         1.000000e+07
# 25%         1.100000e+07
# 50%         1.250000e+07
# 75%         1.400000e+07
# max         1.500000e+09

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["Price_INR_Numeric"], kde=True, color="skyblue")
plt.title("Distribution of Property Prices (in Lakhs ₹)")
plt.xlabel("Price (Lakhs ₹)")
plt.ylabel("Number of Properties")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["Total Area"], bins=30, kde=True, color="orange")
plt.title("Distribution of Total Area (sqft)")
plt.xlabel("Total Area (sqft)")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["BHK"],  discrete=True, color="green")
plt.title("Distribution of BHK Count")
plt.xlabel("BHK")
plt.ylabel("Number of Properties")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
avg_price_per_bhk = df.groupby("BHK")["Price_INR_Numeric"].mean().reset_index()
sns.barplot(x="BHK", y="Price_INR_Numeric", data=avg_price_per_bhk, palette="viridis")
plt.title("Average Property Price per BHK")
plt.xlabel("BHK")
plt.ylabel("Avg Price (Lakhs ₹)")
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_22532\4084739721.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="BHK", y="Price_INR_Numeric", data=avg_price_per_bhk, palette="viridis")

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="BHK", y="Total Area", data=df)
plt.title("Outlier Detection: Total Area per BHK")
plt.xlabel("BHK")
plt.ylabel("Total Area (sqft)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Furnishing", y="Price_INR_Numeric", data=df)
plt.title("Outlier Detection: Price by Furnishing")
plt.xlabel("Furnishing Type")
plt.ylabel("Price (Lakhs ₹)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Total Area", y="Price_INR_Numeric", hue="BHK", data=df, palette="tab10", alpha=0.7)
plt.title("Price vs Total Area with BHK Coloring")
plt.xlabel("Total Area (sqft)")
plt.ylabel("Price (Lakhs ₹)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (1500, 15)
